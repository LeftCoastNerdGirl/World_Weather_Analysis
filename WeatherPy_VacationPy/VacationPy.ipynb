# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests

# Import API key
from api_keys import geoapify_key
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("output_data/cities.csv")

# Display sample data
city_data_df.head()
# Out:
#    City_ID                      City      Lat       Lng  Max Temp  Humidity  \
# 0        0                porto novo   6.4965    2.6036     82.22        83
# 1        1                  hamilton  39.1834  -84.5333     34.09        65
# 2        2  petropavlovsk-kamchatsky  53.0452  158.6483     21.45        63
# 3        3                gua musang   4.8823  101.9644     73.11       100
# 4        4         port-aux-francais -49.3500   70.2167     39.15        74
#
#    Cloudiness  Wind Speed Country        Date
# 0         100        6.35      BJ  1701127003
# 1          20       13.00      US  1701126811
# 2          75       15.99      RU  1701127003
# 3          99        1.39      MY  1701127003
# 4          85       22.28      TF  1701127003

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# %%capture --no-display

# Configure the map plot
map_plot_1 = city_data_df.hvplot.points(
    "Lng",
    "Lat",
    frame_width = 700,
    frame_height = 500,
    tiles = "EsriNatGeo",
    size = "Humidity",
    geo = True,
    scale = 1,
    color = "City"
)

# Display the map
map_plot_1
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit criteria and drop any results with null values
best_weather_df = city_data_df.loc[(city_data_df["Max Temp"] < 27) & (city_data_df["Max Temp"] > 18)]

# Drop any rows with null values
best_weather_df.dropna()

# Display sample data
best_weather_df
# Out:
#      City_ID                      City      Lat       Lng  Max Temp  Humidity  \
# 2          2  petropavlovsk-kamchatsky  53.0452  158.6483     21.45        63
# 20        20         pushkinskiye gory  57.0209   28.9103     20.75        95
# 71        71                 ilulissat  69.2167  -51.1000     26.62        80
# 77        77                   aasiaat  68.7098  -52.8699     19.15        92
# 78        78                   college  64.8569 -147.8028     26.46        90
# 91        91               yellowknife  62.4560 -114.3525     19.92        93
# 111      111                 belyy yar  53.6039   91.3903     21.09        79
# 113      113                    badger  64.8000 -147.5333     26.37        91
# 119      119                  la ronge  55.1001 -105.2842     21.45        79
# 126      126               vilyuchinsk  52.9306  158.4028     22.93        83
# 151      151                   estevan  49.1334 -102.9842     23.22        86
# 154      154               znamenskoye  57.1281   73.8282     20.28        92
# 169      169               elliot lake  46.3834  -82.6331     18.91        83
# 198      198                    fauske  67.2588   15.3918     21.24        80
# 213      213                  turochak  52.2576   87.1224     21.31        97
# 289      289                     nagqu  31.5000   92.0000     19.78        52
# 309      309                  plesetsk  62.7080   40.2916     24.01        90
# 327      327                      hovd  48.0056   91.6419     19.36        86
# 344      344               chibougamau  49.9168  -74.3659     24.42        93
# 345      345              arkhangel'sk  64.5401   40.5433     19.13        88
# 395      395                   svetlyy  54.6750   20.1347     19.36        89
# 404      404                pervomaysk  48.0443   30.8507     20.82        86
# 412      412              sandnessjoen  66.0217   12.6316     21.42        42
# 413      413                 kremenets  50.0969   25.7246     22.05        92
# 427      427                   gagarin  55.5529   34.9954     24.53        97
# 472      472                 kochenevo  55.0218   82.2020     20.59        94
# 479      479          sault ste. marie  46.5168  -84.3333     23.29        84
# 482      482                  usogorsk  63.4106   48.6872     21.67        92
# 507      507                   melfort  52.8667 -104.6177     24.93        86
# 510      510                  kudymkar  59.0173   54.6560     26.33        88
# 522      522                   sol'tsy  58.1239   30.3238     22.53        95
# 536      536             novaya ladoga  60.1025   32.3019     26.58        90
# 553      553                      amos  48.5669  -78.1162     19.94        87
# 572      572               frankenmuth  43.3317  -83.7380     24.89        76
#
#      Cloudiness  Wind Speed Country        Date
# 2            75       15.99      RU  1701127003
# 20          100        7.54      RU  1701127012
# 71           75       12.66      GL  1701127024
# 77          100       14.88      GL  1701127026
# 78          100        0.00      US  1701127026
# 91          100       10.36      CA  1701127029
# 111          75        4.47      RU  1701127034
# 113         100        0.00      US  1701127034
# 119         100       12.66      CA  1701127035
# 126          43        6.80      RU  1701127037
# 151           0        2.30      CA  1701127043
# 154          89        7.63      RU  1701127044
# 169          98       11.48      CA  1701127047
# 198           3        8.32      NO  1701127054
# 213          40        3.22      RU  1701127058
# 289         100        3.00      CN  1701127075
# 309         100       14.85      RU  1701127079
# 327          96        2.80      MN  1701127084
# 344          20        8.05      CA  1701127046
# 345         100       14.43      RU  1701127088
# 395          83        4.14      RU  1701127100
# 404          41        8.66      UA  1701127102
# 412           0        6.91      NO  1701127105
# 413          51        7.23      UA  1701127105
# 427         100        4.79      RU  1701127108
# 472          22        8.12      RU  1701127119
# 479         100       25.32      CA  1701127120
# 482         100       11.56      RU  1701127121
# 507          89        6.91      CA  1701127128
# 510          14        8.97      RU  1701127128
# 522         100        8.84      RU  1701127131
# 536         100       19.46      RU  1701127134
# 553          99       10.94      CA  1701127138
# 572         100       12.66      US  1701127143

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
hotel_df = best_weather_df[["City", "Country", "Lat", "Lng", "Humidity"]].copy()

# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
hotel_df["Hotel Name"] = ""

# Display sample data
hotel_df
# Out:
#                          City Country      Lat       Lng  Humidity Hotel Name
# 2    petropavlovsk-kamchatsky      RU  53.0452  158.6483        63
# 20          pushkinskiye gory      RU  57.0209   28.9103        95
# 71                  ilulissat      GL  69.2167  -51.1000        80
# 77                    aasiaat      GL  68.7098  -52.8699        92
# 78                    college      US  64.8569 -147.8028        90
# 91                yellowknife      CA  62.4560 -114.3525        93
# 111                 belyy yar      RU  53.6039   91.3903        79
# 113                    badger      US  64.8000 -147.5333        91
# 119                  la ronge      CA  55.1001 -105.2842        79
# 126               vilyuchinsk      RU  52.9306  158.4028        83
# 151                   estevan      CA  49.1334 -102.9842        86
# 154               znamenskoye      RU  57.1281   73.8282        92
# 169               elliot lake      CA  46.3834  -82.6331        83
# 198                    fauske      NO  67.2588   15.3918        80
# 213                  turochak      RU  52.2576   87.1224        97
# 289                     nagqu      CN  31.5000   92.0000        52
# 309                  plesetsk      RU  62.7080   40.2916        90
# 327                      hovd      MN  48.0056   91.6419        86
# 344               chibougamau      CA  49.9168  -74.3659        93
# 345              arkhangel'sk      RU  64.5401   40.5433        88
# 395                   svetlyy      RU  54.6750   20.1347        89
# 404                pervomaysk      UA  48.0443   30.8507        86
# 412              sandnessjoen      NO  66.0217   12.6316        42
# 413                 kremenets      UA  50.0969   25.7246        92
# 427                   gagarin      RU  55.5529   34.9954        97
# 472                 kochenevo      RU  55.0218   82.2020        94
# 479          sault ste. marie      CA  46.5168  -84.3333        84
# 482                  usogorsk      RU  63.4106   48.6872        92
# 507                   melfort      CA  52.8667 -104.6177        86
# 510                  kudymkar      RU  59.0173   54.6560        88
# 522                   sol'tsy      RU  58.1239   30.3238        95
# 536             novaya ladoga      RU  60.1025   32.3019        90
# 553                      amos      CA  48.5669  -78.1162        87
# 572               frankenmuth      US  43.3317  -83.7380        76

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# Set parameters to search for a hotel
radius = 10000
params = {
    "categories": "accommodation.hotel",
    "apiKey":geoapify_key,
    "limit": 1
}

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # get latitude, longitude from the DataFrame
    latitude = row["Lat"]
    longitude = row["Lng"]
        
    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{longitude},{latitude},{radius}"
    params["bias"] = f"proximity:{longitude},{latitude}"
    
    # Set base URL
    base_url = "https://api.geoapify.com/v2/places?"


    # Make an API request using the params dictionary
    name_address = requests.get(base_url, params=params)
    
    # Convert the API response to JSON format
    name_address = name_address.json()
    
    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# petropavlovsk-kamchatsky - nearest hotel: ООО Постоялый двор
# pushkinskiye gory - nearest hotel: Дружба
# ilulissat - nearest hotel: Best Western Plus Hotel Ilulissat
# aasiaat - nearest hotel: SØMA
# college - nearest hotel: BEST WESTERN PLUS Pioneer Park Inn
# yellowknife - nearest hotel: No hotel found
# belyy yar - nearest hotel: No hotel found
# badger - nearest hotel: Hotel North Pole
# la ronge - nearest hotel: La Ronge Hotel and Suites
# vilyuchinsk - nearest hotel: Победа
# estevan - nearest hotel: Days Inn
# znamenskoye - nearest hotel: No hotel found
# elliot lake - nearest hotel: Hampton Inn Elliot Lake
# fauske - nearest hotel: Scandic Fauske
# turochak - nearest hotel: Гостинница администрации
# nagqu - nearest hotel: Naqu Hotel
# plesetsk - nearest hotel: Плесецкая
# hovd - nearest hotel: Khovd hotel
# chibougamau - nearest hotel: No hotel found
# arkhangel'sk - nearest hotel: Серафима
# svetlyy - nearest hotel: Гостиница Спортивная
# pervomaysk - nearest hotel: No hotel found
# sandnessjoen - nearest hotel: Scandic Syv Søstre
# kremenets - nearest hotel: Старе місто
# gagarin - nearest hotel: Гостиница Восток
# kochenevo - nearest hotel: No hotel found
# sault ste. marie - nearest hotel: Holiday Inn
# usogorsk - nearest hotel: Единственная
# melfort - nearest hotel: No hotel found
# kudymkar - nearest hotel: No hotel found
# sol'tsy - nearest hotel: Уют
# novaya ladoga - nearest hotel: Радуга
# amos - nearest hotel: Hôtel des Eskers
# frankenmuth - nearest hotel: Fairfield Inn & Suites - Frankenmuth
#                          City Country      Lat       Lng  Humidity  \
# 2    petropavlovsk-kamchatsky      RU  53.0452  158.6483        63
# 20          pushkinskiye gory      RU  57.0209   28.9103        95
# 71                  ilulissat      GL  69.2167  -51.1000        80
# 77                    aasiaat      GL  68.7098  -52.8699        92
# 78                    college      US  64.8569 -147.8028        90
# 91                yellowknife      CA  62.4560 -114.3525        93
# 111                 belyy yar      RU  53.6039   91.3903        79
# 113                    badger      US  64.8000 -147.5333        91
# 119                  la ronge      CA  55.1001 -105.2842        79
# 126               vilyuchinsk      RU  52.9306  158.4028        83
# 151                   estevan      CA  49.1334 -102.9842        86
# 154               znamenskoye      RU  57.1281   73.8282        92
# 169               elliot lake      CA  46.3834  -82.6331        83
# 198                    fauske      NO  67.2588   15.3918        80
# 213                  turochak      RU  52.2576   87.1224        97
# 289                     nagqu      CN  31.5000   92.0000        52
# 309                  plesetsk      RU  62.7080   40.2916        90
# 327                      hovd      MN  48.0056   91.6419        86
# 344               chibougamau      CA  49.9168  -74.3659        93
# 345              arkhangel'sk      RU  64.5401   40.5433        88
# 395                   svetlyy      RU  54.6750   20.1347        89
# 404                pervomaysk      UA  48.0443   30.8507        86
# 412              sandnessjoen      NO  66.0217   12.6316        42
# 413                 kremenets      UA  50.0969   25.7246        92
# 427                   gagarin      RU  55.5529   34.9954        97
# 472                 kochenevo      RU  55.0218   82.2020        94
# 479          sault ste. marie      CA  46.5168  -84.3333        84
# 482                  usogorsk      RU  63.4106   48.6872        92
# 507                   melfort      CA  52.8667 -104.6177        86
# 510                  kudymkar      RU  59.0173   54.6560        88
# 522                   sol'tsy      RU  58.1239   30.3238        95
# 536             novaya ladoga      RU  60.1025   32.3019        90
# 553                      amos      CA  48.5669  -78.1162        87
# 572               frankenmuth      US  43.3317  -83.7380        76
#
#                                Hotel Name
# 2                      ООО Постоялый двор
# 20                                 Дружба
# 71      Best Western Plus Hotel Ilulissat
# 77                                   SØMA
# 78     BEST WESTERN PLUS Pioneer Park Inn
# 91                         No hotel found
# 111                        No hotel found
# 113                      Hotel North Pole
# 119             La Ronge Hotel and Suites
# 126                                Победа
# 151                              Days Inn
# 154                        No hotel found
# 169               Hampton Inn Elliot Lake
# 198                        Scandic Fauske
# 213              Гостинница администрации
# 289                            Naqu Hotel
# 309                             Плесецкая
# 327                           Khovd hotel
# 344                        No hotel found
# 345                              Серафима
# 395                  Гостиница Спортивная
# 404                        No hotel found
# 412                    Scandic Syv Søstre
# 413                           Старе місто
# 427                      Гостиница Восток
# 472                        No hotel found
# 479                           Holiday Inn
# 482                          Единственная
# 507                        No hotel found
# 510                        No hotel found
# 522                                   Уют
# 536                                Радуга
# 553                      Hôtel des Eskers
# 572  Fairfield Inn & Suites - Frankenmuth

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# %%capture --no-display

# Configure the map plot
hotel_map_plot = hotel_df.hvplot.points("Lng", "Lat",
                                       geo=True,
                                       tiles="EsriNatGeo",
                                       color="City",
                                       size="Humidity",
                                       hover_cols=["Hotel Name", "Country"],
                                       frame_width=700,
                                       frame_height=600)

# Display the map
hotel_map_plot
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity,Hotel Name,Country)
